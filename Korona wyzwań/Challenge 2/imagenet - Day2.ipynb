# %%
from keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
from keras.preprocessing import image
import numpy as np
import requests
from io import BytesIO
from PIL import Image

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102858752/102853048 [==============================] - 23s 0us/step

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %%
url_image ='https://www.wprost.pl/_thumb/76/a5/701564e617ac922b9d9c19c3bf4d.jpeg'

# %% [markdown]
# ![](https://www.wprost.pl/_thumb/76/a5/701564e617ac922b9d9c19c3bf4d.jpeg)

# %%
response = requests.get(url_image)
img = Image.open(BytesIO(response.content))
img = img.resize((224,224))

# %%
X = image.img_to_array(img)
X =np.expand_dims(X,axis=0)
X.shape
# Out:
# (224, 224, 3)

# %%
X =np.expand_dims(X,axis=0)

# %%
X.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(X)

# %%
y_pred
# Out:
# array([[7.72781839e-10, 1.66096026e-08, 8.09838454e-08, 4.96632913e-09,
#         3.79172027e-09, 5.10114120e-08, 4.29034896e-09, 4.90550267e-09,
#         3.06687070e-07, 1.67250338e-08, 3.45840445e-09, 1.98459715e-09,
#         4.83273022e-09, 2.63762381e-08, 6.97027680e-09, 3.21995088e-08,
#         3.00535739e-08, 1.44238001e-07, 8.69580887e-08, 2.88270350e-08,
#         9.44855927e-08, 3.16433386e-08, 3.51987666e-08, 8.12149015e-09,
#         4.10690397e-08, 3.27519262e-10, 5.09110532e-10, 1.04356008e-08,
#         3.29497374e-10, 2.13717333e-09, 1.37645362e-09, 2.34055086e-09,
#         7.35709216e-10, 2.88495161e-09, 6.44218634e-09, 3.47279450e-09,
#         2.05391331e-08, 6.10966744e-09, 2.43195042e-09, 1.96953609e-09,
#         7.57893215e-09, 3.23758687e-09, 8.10189804e-10, 5.97912075e-09,
#         1.73570114e-09, 2.03434780e-09, 4.52097959e-09, 1.73950254e-09,
#         4.34243613e-10, 6.06732442e-10, 1.92752614e-09, 1.35436737e-08,
# ...

# %%
decode_predictions(y_pred, top=3)
# Out:
# ...
# 40960/35363 [==================================] - 0s 2us/step
# [[('n02123394', 'Persian_cat', 0.99551976),
#   ('n02328150', 'Angora', 0.0031523115),
#   ('n02086079', 'Pekinese', 0.00034739292)]]

# %%
url_image_iphone ='https://image.ceneostatic.pl/data/products/85615932/i-apple-iphone-11-64gb-czarny.jpg'

# %%
response = requests.get(url_image_iphone)
img_iphone = Image.open(BytesIO(response.content))
img_iphone = img_iphone.resize((224,224))

# %%
X = image.img_to_array(img_iphone)
X =np.expand_dims(X,axis=0)
X.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(X)

# %%
decode_predictions(y_pred, top=3)
# Out:
# [[('n03584254', 'iPod', 0.35574585),
#   ('n03793489', 'mouse', 0.10422893),
#   ('n03314780', 'face_powder', 0.074673556)]]

# %% [markdown]
# ![_](https://elektrowoz.pl/wp-content/uploads/2020/02/Tesla-Model-Y-ostateczna-wersja.jpg)

# %%
url_tesla = 'https://elektrowoz.pl/wp-content/uploads/2020/02/Tesla-Model-Y-ostateczna-wersja.jpg'

# %%
response = requests.get(url_tesla)
img_tesla = Image.open(BytesIO(response.content))
img_tesla = img_tesla.resize((224,224))
X = image.img_to_array(img_tesla)
X =np.expand_dims(X,axis=0)

# %%
y_pred = model.predict(X)

# %%
decode_predictions(y_pred, top=5)
# Out:
# [[('n03770679', 'minivan', 0.5140342),
#   ('n03930630', 'pickup', 0.10742718),
#   ('n02974003', 'car_wheel', 0.092254296),
#   ('n03459775', 'grille', 0.09106374),
#   ('n03670208', 'limousine', 0.047960095)]]
