# %%
import gzip
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models import Word2Vec, LdaMulticore
from gensim.corpora import Dictionary
import numpy as np
import pyLDAvis
from pyLDAvis import gensim

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 588D-4BF9
#
#  Directory of C:\Users\benia\Desktop\Machine_Learning\Korona wyzwaä\Challenge 4\data\data
#
# 03.09.2019  10:30    <DIR>          .
# 03.09.2019  10:30    <DIR>          ..
# 03.09.2019  10:30       240˙342˙787 reviews_data.txt
#                1 File(s)    240˙342˙787 bytes
#                2 Dir(s)  19˙764˙211˙712 bytes free

# %%
cd data
# Out:
# C:\Users\benia\Desktop\Machine_Learning\Korona wyzwań\Challenge 4\data\data

# %%
with open("reviews_data.txt", "rb") as f:
    for i,line in enumerate(f):
        print(i,line)
        print(" ")
        break
# Out:
# 0 b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites i
# ...

# %%
def preprocesing(sentence):
    [word for word in simple_preprocess(sentence) if word not in STOPWORDS]

def read_sentences(filename):
    with open(filename, "rb") as f:
        for line in f:
            yield preprocesing(line)

# %%
sentences =list(read_sentences("reviews_data.txt"))

# %%
sentences
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
sentence = "\tExcellent value - location not a big problem."
[word for word in simple_preprocess(sentence) if word not in STOPWORDS]
# Out:
# ['excellent', 'value', 'location', 'big', 'problem']

# %%
[STOPWORDS]
# Out:
# [frozenset({'a',
#             'about',
#             'above',
#             'across',
#             'after',
#             'afterwards',
#             'again',
#             'against',
#             'all',
#             'almost',
#             'alone',
#             'along',
#             'already',
#             'also',
#             'although',
#             'always',
#             'am',
#             'among',
#             'amongst',
#             'amoungst',
#             'amount',
#             'an',
#             'and',
#             'another',
#             'any',
#             'anyhow',
#             'anyone',
#             'anything',
#             'anyway',
#             'anywhere',
#             'are',
#             'around',
#             'as',
#             'at',
#             'back',
#             'be',
#             'became',
#             'because',
#             'become',
#             'becomes',
#             'becoming',
#             'been',
# ...

# %%
len(sentences)
# Out:
# 255404

# %%
sentences
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %% [markdown]
# # Model

# %%
model = Word2Vec(sentences,size=100,window=5,min_count=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-3874e432f29d> in <module>
# ----> 1 model = Word2Vec(sentences,size=100,window=5,min_count=2)
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     781             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#     782             seed=seed, hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# --> 783             fast_version=FAST_VERSION)
#     784
# ...

# %%
model = Word2Vec.load("models/hotel_model_size100_window10_mincount2.model")

# %%
model.wv.most_similar("good")
# Out:
# [('decent', 0.7995322346687317),
#  ('great', 0.7496006488800049),
#  ('excellent', 0.7420488595962524),
#  ('fair', 0.6252300143241882),
#  ('ok', 0.6243417263031006),
#  ('average', 0.592189371585846),
#  ('reasonable', 0.5821888446807861),
#  ('nice', 0.5542483925819397),
#  ('wise', 0.5451887845993042),
#  ('fine', 0.5380234718322754)]

# %%
model.wv.most_similar("bad")
# Out:
# [('terrible', 0.7091025114059448),
#  ('horrible', 0.6725283861160278),
#  ('awful', 0.6613410711288452),
#  ('okay', 0.6073172092437744),
#  ('sucked', 0.6060259342193604),
#  ('poor', 0.6045094728469849),
#  ('crappy', 0.6011784076690674),
#  ('ok', 0.5935438871383667),
#  ('complain', 0.5927609205245972),
#  ('worse', 0.5925099849700928)]

# %%
model.wv.most_similar(positive=["bad"],negative=["good"])
# Out:
# [('terrified', 0.5788648128509521),
#  ('mortified', 0.578603982925415),
#  ('nightmares', 0.5188339948654175),
#  ('begin', 0.5178046822547913),
#  ('punishment', 0.5144330263137817),
#  ('scared', 0.5112849473953247),
#  ('nasty', 0.5061407685279846),
#  ('pissed', 0.5049529075622559),
#  ('horror', 0.5036149621009827),
#  ('ugh', 0.500980794429779)]

# %% [markdown]
# # Topic Modeling LDA

# %%
sentence_light = np.random.permutation(sentences)

# %%
sentence_light= sentence_light[:1000]

# %%
dictinary = Dictionary(sentence_light)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-11ca57551090> in <module>
# ----> 1 dictinary = Dictionary(sentence_light)
#
# ~\Anaconda3\lib\site-packages\gensim\corpora\dictionary.py in __init__(self, documents, prune_at)
#      85
#      86         if documents is not None:
# ---> 87             self.add_documents(documents, prune_at=prune_at)
#      88
#      89     def __getitem__(self, tokenid):
#
# ~\Anaconda3\lib\site-packages\gensim\corpora\dictionary.py in add_documents(self, documents, prune_at)
#     206
#     207             # update Dictionary with the document
# --> 208             self.doc2bow(document, allow_update=True)  # ignore the result, here we only care about updating token ids
#     209
#     210         logger.info(
#
# ...
