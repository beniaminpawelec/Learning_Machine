# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('./data/car.h5')

# %%
df.head()
# Out:
#                                           breadcrumb           created_at  \
# 0    [Osobowe, Dacia, Logan, Dacia Logan II (2012-)]  13:23, 5 marca 2018
# 2  [Osobowe, Peugeot, 3008, Peugeot 3008 I (2009-...  15:48, 5 marca 2018
# 3  [Osobowe, Porsche, Cayenne, Porsche Cayenne II...  06:30, 4 marca 2018
# 4  [Osobowe, Peugeot, 308, Peugeot 308 T7 (2008-2...  08:46, 3 marca 2018
# 5  [Osobowe, Volkswagen, Golf, Volkswagen Golf VI...  20:00, 3 marca 2018
#
#   price_currency                            price_details  price_value  \
# 0            PLN                              Cena Brutto      45100.0
# 2            PLN  Cena Brutto, Do negocjacji, Faktura VAT      28000.0
# 3            PLN   Cena Netto, Do negocjacji, Faktura VAT     229500.0
# 4            PLN               Cena Brutto, Do negocjacji      19500.0
# 5            PLN                 Cena Brutto, Faktura VAT     164900.0
#
#                                       seller_address  \
# ...

# %%
df.shape
# Out:
# (106494, 155)

# %%
df.sample(5)
# Out:
#                                                breadcrumb  \
# 97353         [Osobowe, Audi, A6, Audi A6 C5 (1997-2004)]
# 73009   [Osobowe, Renault, Clio, Renault Clio II (1998...
# 15845    [Osobowe, Ford, Fiesta, Ford Fiesta Mk7 (2008-)]
# 127944                          [Osobowe, Peugeot, Boxer]
# 97262   [Osobowe, Volkswagen, Golf, Volkswagen Golf VI...
#
#                    created_at price_currency               price_details  \
# 97353     17:07, 4 marca 2018            PLN  Cena Brutto, Do negocjacji
# 73009     10:32, 1 marca 2018            PLN  Cena Brutto, Do negocjacji
# 15845   20:22, 25 lutego 2018            PLN  Cena Brutto, Do negocjacji
# 127944    14:32, 3 marca 2018            PLN                 Cena Brutto
# 97262   20:55, 23 lutego 2018            PLN  Cena Brutto, Do negocjacji
#
#         price_value                                     seller_address  \
# 97353       10900.0                Bodzentyn, kielecki, Świętokrzyskie
# ...
